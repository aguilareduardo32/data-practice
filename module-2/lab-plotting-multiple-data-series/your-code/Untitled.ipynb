# %%
import pandas as pd
import seaborn as sns

# %%
data= pd.read_csv(r'C:\Users\Yael Aguilar\Downloads/vehicles.csv')

# %%
data.boxplot(column = 'Combined MPG')
# Out:
# <AxesSubplot:>

# %%
ax = sns.boxplot(x = 'Fuel Type', y = 'Highway MPG', data= data)
ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)
# Out:
# [Text(0, 0, 'Regular'),
#  Text(1, 0, 'Premium'),
#  Text(2, 0, 'Diesel'),
#  Text(3, 0, 'Premium and Electricity'),
#  Text(4, 0, 'Premium or E85'),
#  Text(5, 0, 'Premium Gas or Electricity'),
#  Text(6, 0, 'Gasoline or E85'),
#  Text(7, 0, 'Gasoline or natural gas'),
#  Text(8, 0, 'CNG'),
#  Text(9, 0, 'Regular Gas or Electricity'),
#  Text(10, 0, 'Midgrade'),
#  Text(11, 0, 'Regular Gas and Electricity'),
#  Text(12, 0, 'Gasoline or propane')]

# %%
cyl = [6.0, 4.0]
#data.Cylinders.isin(cyl)
data1 = data[data['Cylinders'].isin(cyl)]
data1.shape
# Out:
# (26259, 15)

# %%
ax = sns.boxplot(x = 'Fuel Type', y = 'Highway MPG', hue = 'Cylinders',
                 data= data1, palette = 'Set3')
ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)
# Out:
# [Text(0, 0, 'Regular'),
#  Text(1, 0, 'Premium'),
#  Text(2, 0, 'Diesel'),
#  Text(3, 0, 'Premium and Electricity'),
#  Text(4, 0, 'Premium or E85'),
#  Text(5, 0, 'Gasoline or E85'),
#  Text(6, 0, 'Premium Gas or Electricity'),
#  Text(7, 0, 'Gasoline or natural gas'),
#  Text(8, 0, 'Regular Gas or Electricity'),
#  Text(9, 0, 'CNG'),
#  Text(10, 0, 'Midgrade'),
#  Text(11, 0, 'Regular Gas and Electricity')]

# %%
sns.violinplot('Combined MPG', data = data)
# Out:
# C:\Users\Yael Aguilar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Combined MPG'>

# %%
data['Fuel Barrels/Year'].hist()
# Out:
# <AxesSubplot:>

# %%
sns.displot(data['Fuel Barrels/Year'], bins = 20)

# %%
data['Drivetrain'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
ax = sns.barplot(x = 'Fuel Type', y = 'Highway MPG', hue = 'Cylinders', data = data1)
ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)
# Out:
# [Text(0, 0, 'Regular'),
#  Text(1, 0, 'Premium'),
#  Text(2, 0, 'Diesel'),
#  Text(3, 0, 'Premium and Electricity'),
#  Text(4, 0, 'Premium or E85'),
#  Text(5, 0, 'Gasoline or E85'),
#  Text(6, 0, 'Premium Gas or Electricity'),
#  Text(7, 0, 'Gasoline or natural gas'),
#  Text(8, 0, 'Regular Gas or Electricity'),
#  Text(9, 0, 'CNG'),
#  Text(10, 0, 'Midgrade'),
#  Text(11, 0, 'Regular Gas and Electricity')]

# %%
data.boxplot(column = 'Combined MPG')
# Out:
# <AxesSubplot:>

# %%
ax = sns.boxplot(x = 'Fuel Type', y = 'Highway MPG', data= data)
ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)
# Out:
# [Text(0, 0, 'Regular'),
#  Text(1, 0, 'Premium'),
#  Text(2, 0, 'Diesel'),
#  Text(3, 0, 'Premium and Electricity'),
#  Text(4, 0, 'Premium or E85'),
#  Text(5, 0, 'Premium Gas or Electricity'),
#  Text(6, 0, 'Gasoline or E85'),
#  Text(7, 0, 'Gasoline or natural gas'),
#  Text(8, 0, 'CNG'),
#  Text(9, 0, 'Regular Gas or Electricity'),
#  Text(10, 0, 'Midgrade'),
#  Text(11, 0, 'Regular Gas and Electricity'),
#  Text(12, 0, 'Gasoline or propane')]

# %%
cyl = [6.0, 4.0]
data.Cylinders.isin(cyl)
data1 = data[data.Cylinders.isin(cyl)]
data1.shape
# Out:
# (26259, 15)

# %%
ax = sns.boxplot(x = 'Fuel Type', y ='Highway MPG', hue = 'Cylinders', data = data1, palette = 'Set3')
ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)
# Out:
# [Text(0, 0, 'Regular'),
#  Text(1, 0, 'Premium'),
#  Text(2, 0, 'Diesel'),
#  Text(3, 0, 'Premium and Electricity'),
#  Text(4, 0, 'Premium or E85'),
#  Text(5, 0, 'Gasoline or E85'),
#  Text(6, 0, 'Premium Gas or Electricity'),
#  Text(7, 0, 'Gasoline or natural gas'),
#  Text(8, 0, 'Regular Gas or Electricity'),
#  Text(9, 0, 'CNG'),
#  Text(10, 0, 'Midgrade'),
#  Text(11, 0, 'Regular Gas and Electricity')]

# %%
sns.violinplot('Combined MPG', data = data)
# Out:
# C:\Users\Yael Aguilar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Combined MPG'>

# %%
data['Fuel Barrels/Year'].hist()
# Out:
# <AxesSubplot:>

# %%
data['Fuel Barrels/Year'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
x = data['Fuel Type']
ax = sns.displot(x)
ax.set_xticklabels( rotation = 90)

# %%
data['Fuel Type'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
data['Drivetrain'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
ax = sns.barplot(x = 'Fuel Type', y = 'Highway MPG', hue = 'Cylinders', data = data)
ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)
# Out:
# [Text(0, 0, 'Regular'),
#  Text(1, 0, 'Premium'),
#  Text(2, 0, 'Diesel'),
#  Text(3, 0, 'Premium and Electricity'),
#  Text(4, 0, 'Premium or E85'),
#  Text(5, 0, 'Premium Gas or Electricity'),
#  Text(6, 0, 'Gasoline or E85'),
#  Text(7, 0, 'Gasoline or natural gas'),
#  Text(8, 0, 'CNG'),
#  Text(9, 0, 'Regular Gas or Electricity'),
#  Text(10, 0, 'Midgrade'),
#  Text(11, 0, 'Regular Gas and Electricity'),
#  Text(12, 0, 'Gasoline or propane')]

# %%
s = data[data['Cylinders'] == 12]['Model']
# Out:
# 370                  DB AR1
# 371                  DB AR1
# 372           DB-7 GT Coupe
# 373         DB-7 GT Volante
# 374      DB-7 Vantage Coupe
#                 ...
# 35919          Wetl 600 SEL
# 35920             Wetl 850I
# 35921             Wetl 850I
# 35922       Wetl Testarossa
# 35923       Wetl Testarossa
# Name: Model, Length: 562, dtype: object

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

figure(figsize=(12, 20))
xtick_loc = [0.20]


cyl = [8]
data2 = data[data.Cylinders.isin(cyl)][:100]
data2.Model.value_counts().plot.bar()
#ax.set_xticklabels(rotation = (45), fontsize = 10, va='bottom', ha='left')
# Out:
# <AxesSubplot:>

# %%
data2['Model'].hist()
# Out:
# <AxesSubplot:>
