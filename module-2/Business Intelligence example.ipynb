# %%
import pandas as pd
import matplotlib.pyplot as plt
import random
import numpy as np
#%matplotlib inline

# %%
# values for X axis bar separation:

x_values1 = [20.8, 24.8, 28.8, 32.8, 36.8, 40.8,44.8,48.8,52.8,56.8,60.8,64.8]
x_values2 = [21.6,25.6,29.6,33.6,37.6,41.6,45.8,49.8,53.8,57.8,61.8,65.8]
x_values3 = [22.6,26.6,30.6,34.6,38.6,42.6,46.8,50.8,54.8,58.8,62.8,66.8]

#Sales by month and labels:

drinks = ['cappuchino', 'latte', 'chai', 'americano', 'mocha', 'espresso']
months = ['JAN', 'FEB', 'MARCH', 'APRIL', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']
sales_cappuchino = random.sample(range(10,100), 12)
sales_latte = random.sample(range(10,100), 12)
sales_chai = random.sample(range(10,100), 12)

# %%
fig = plt.figure(figsize=(20,18))

ax = plt.subplot()
ax.set_xticks(x)
ax.set_xticklabels(['JAN', 'FEB', 'MARCH', 'APRIL', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC'])


plt.bar(x_values1,sales_cappuchino)
plt.bar(x_values2,sales_latte)
plt.bar(x_values3, sales_chai)


plt.title('Coffe Sales Comparision')
plt.xlabel('Types of coffes')
plt.ylabel('Pound sold')
plt.legend(labels = drinks, loc = 'upper right')
plt.show()

# %%
x = []
for i in range(22,70,4):
    x.append(i)

# %%
x
# Out:
# [20, 24, 28, 32, 36, 40, 44, 48, 52, 56, 60, 64]

# %%
#Product identification & sales per product.

product = ['Computer', 'Keyboard', ' Headset', 'Mouse', 'Monitor']

sales_c = np.random.randint(1000,3000,5)
sales_k = np.random.randint(1000,3000,5)
sales_h = np.random.randint(1000,3000,5)
sales_m = np.random.randint(1000,3000,5)
sales_o = np.random.randint(1000,3000,5)



#configure buttons to stack bars:
k_bottom = np.add(sales_c, sales_k)
h_bottom = np.add(k_bottom, sales_h)
m_bottom = np.add(h_bottom, sales_m)


#Create figure and axes:
fig = plt.figure(figsize=(10,8))
ax = plt.subplot()

#Plot bars individually:

plt.bar(range(len(sales_c)),sales_c, color='#D50071', label=product[0])
plt.bar(range(len(sales_k)),sales_k, bottom=sales_c, color='#0040FF',label=product[1])
plt.bar(range(len(sales_h)),sales_h, bottom=k_bottom, color='#00CA70',label=product[2])
plt.bar(range(len(sales_m)),sales_m, bottom=h_bottom, color='#C14200',label=product[3])
plt.bar(range(len(sales_o)),sales_o, bottom=m_bottom, color='#F0C300',label=product[4])

#Display graphs:

ax.set_xticks(range(5))
ax.set_xticklabels(['Monday', 'Tuesday', 'Wednesday', 'Thurday', 'Friday'])
plt.legend(loc=  'best')
plt.title('Sales Distribution by Product')
plt.ylabel('Products Sold')
plt.show()
