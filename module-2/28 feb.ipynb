# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#vehicles = pd.read_csv(r'C:\Users\Yael Aguilar\Downloads\vehicles.csv')

# %%
vehicles.sort_values(by=['CO2 Emission Grams/Mile', 'City MPG', 'Highway MPG'], inplace = True)
vehicles.plot(x = 'CO2 Emission Grams/Mile', y = ['City MPG', 'Highway MPG'])
# Out:
# <AxesSubplot:xlabel='CO2 Emission Grams/Mile'>

# %%
vehicles_mean = vehicles[['Highway MPG', 'City MPG', 'Drivetrain']].groupby(['Drivetrain']).mean()
vehicles_mean.plot.barh()
# Out:
# <AxesSubplot:ylabel='Drivetrain'>

# %%
data = pd.read_csv(r'C:\Users\Yael Aguilar\Downloads\fortune1000.csv', encoding = 'unicode_escape')
data.head()
# Out:
#    rank               title Previous Rank Revenues ($M) Revenue Change  \
# 0     1             Walmart             1     $500,343           3.00%
# 1     2         Exxon Mobil             4     $244,363          17.40%
# 2     3  Berkshire Hathaway             2     $242,137           8.30%
# 3     4               Apple             3     $229,234           6.30%
# 4     5  UnitedHealth Group             6     $201,159           8.80%
#
#   Profits ($M) Profit Change Assets ($M) Mkt Value as of 3/29/18 ($M)  \
# 0   $9,862.00        -27.70%   $204,522                     $263,563
# 1  $19,710.00        151.40%   $348,691                     $316,157
# 2  $44,940.00         86.70%   $702,095                     $492,008
# 3  $48,351.00          5.80%   $375,319                     $851,318
# 4  $10,558.00         50.50%   $139,058                     $207,080
#
#    Employees                  CEO  \
# 0  2,300,000  C. Douglas McMillon
# 1     71,200      Darren W. Woods
# ...

# %%
data['Sector'].value_counts().plot.barh()
# Out:
# <AxesSubplot:>

# %%
import squarify
from matplotlib.pyplot import figure

figure(figsize=(18, 12), dpi=80)

# %%
a = data['Sector'].value_counts().index
a
# Out:
# Index(['Financials', 'Energy', 'Technology', 'Retailing', 'Health Care',
#        'Business Services', 'Industrials', 'Materials', 'Wholesalers',
#        'Transportation', 'Food, Beverages &  Tobacco', 'Chemicals',
#        'Household Products', 'Engineering &  Construction',
#        'Hotels, Restaurants &  Leisure', 'Media', 'Aerospace &  Defense',
#        'Motor Vehicles &  Parts', 'Apparel', 'Food &  Drug Stores',
#        'Telecommunications'],
#       dtype='object')

# %%
figure(figsize=(18, 12), dpi=80)
squarify.plot(data['Sector'].value_counts(), label = a, alpha = .9)
# Out:
# <AxesSubplot:>

# %%
import plotly.express as px

fig =px.scatter(data['Sector'].value_counts(), size =data['Sector'].value_counts(), color = data['Sector'].value_counts())
fig.show()
# Out:
# <div>                            <div id="a25e914f-039b-4f6f-981b-f0fe36abbc78" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a25e914f-039b-4f6f-981b-f0fe36abbc78")) {                    Plotly.newPlot(                        "a25e914f-039b-4f6f-981b-f0fe36abbc78",                        [{"hovertemplate": "index=%{x}<br>value=%{y}<br>size=%{marker.size}<br>color=%{marker.color}<extra></extra>", "legendgroup": "", "marker": {"color": [155, 107, 103, 77, 71, 53, 49, 45, 44, 40, 37, 33, 28, 27, 26, 25, 25, 19, 14, 12, 10], "coloraxis": "coloraxis", "size": [155, 107, 103, 77, 71, 53, 49, 45, 44, 40, 37, 33, 28, 27, 26, 25, 25, 19, 14, 12, 10], "sizemode": "area", "sizeref": 0.3875, "symbol": "circle"}, "mode": "markers", "name": "", "orientation": "
# ...

# %%
data.size
# Out:
# 19000

# %%
import numpy as np


plt.scatter(data['Revenues ($M)'], data['Profits ($M)'])
plt.show()

# %%
from plotly.graph_objs import Scatter
import pandas as pd

fortune= data

data = [Scatter(x=fortune['Revenues ($M)'], y=fortune['Profits ($M)'], mode = 'markers', text=fortune['title'])]


fig = Figure(data=data)

plotly.offline.iplot(fig, show_link=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-80-60182e2c1694> in <module>
#       4 fortune= data
#       5
# ----> 6 data = [Scatter(x=fortune['Revenues ($M)'], y=fortune['Profits ($M)'], mode = 'markers', text=fortune['title'])]
#       7
#       8
#
# TypeError: list indices must be integers or slices, not str

# %%
data.groupby(['title']).mean()
# Out:
#                         rank   Latitude   Longitude
# title
# 3M                        97  44.953703  -93.089958
# 99 Cents Only Stores     910  34.000569 -118.159793
# A-Mark Precious Metals   404  33.919180 -118.416465
# A. Schulman              837  41.127833  -81.609844
# A.O. Smith               732  43.038902  -87.906474
# ...                      ...        ...         ...
# Zions Bancorp.           785  40.760779 -111.891047
# Zoetis                   507  40.865286  -74.417388
# eBay                     309  37.338208 -121.886329
# iHeartMedia              452  29.424122  -98.493628
# salesforce.com           285  37.774929 -122.419415
#
# [1000 rows x 3 columns]

# %%
data = data[data]
